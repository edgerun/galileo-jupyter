# %%
from galileojp.frames import MixedExperimentFrameGateway
from galileojp.widgets import experiment_dropdown

# %%
fgw = MixedExperimentFrameGateway.from_env()
print(fgw)

# %%
exp_id = '202109091734-4405'

# %%
fgw.events(exp_id)
# Out:
#                                 result table                    _start  \
# ts
# 2021-09-09 15:35:00.087136507  _result     0 1970-01-01 00:00:00+00:00
# 2021-09-09 15:35:00.087396145  _result     1 1970-01-01 00:00:00+00:00
# 2021-09-09 15:35:00.087557316  _result     2 1970-01-01 00:00:00+00:00
# 2021-09-09 15:35:00.087750435  _result     3 1970-01-01 00:00:00+00:00
# 2021-09-09 15:35:00.087858915  _result     4 1970-01-01 00:00:00+00:00
# ...                                ...   ...                       ...
# 2021-09-09 15:35:00.111345053  _result    59 1970-01-01 00:00:00+00:00
# 2021-09-09 15:35:00.111631632  _result    60 1970-01-01 00:00:00+00:00
# 2021-09-09 15:35:00.111814499  _result    61 1970-01-01 00:00:00+00:00
# 2021-09-09 15:35:00.112092733  _result    62 1970-01-01 00:00:00+00:00
# 2021-09-09 15:35:00.112326860  _result    63 1970-01-01 00:00:00+00:00
#
#                                                          _stop  \
# ts
# ...

# %%
fgw.telemetry(exp_id)
# Out:
#                                 result table                    _start  \
# ts
# 2021-09-09 10:53:59.578461409  _result     0 1970-01-01 00:00:00+00:00
# 2021-09-09 10:53:59.779963732  _result     1 1970-01-01 00:00:00+00:00
# 2021-09-09 10:54:00.579350710  _result     2 1970-01-01 00:00:00+00:00
# 2021-09-09 10:54:00.789165735  _result     3 1970-01-01 00:00:00+00:00
# 2021-09-09 10:54:01.578443289  _result     4 1970-01-01 00:00:00+00:00
# ...                                ...   ...                       ...
# 2021-09-09 10:54:04.770092010  _result  2242 1970-01-01 00:00:00+00:00
# 2021-09-09 10:54:04.775995016  _result  2243 1970-01-01 00:00:00+00:00
# 2021-09-09 10:54:04.782766104  _result  2244 1970-01-01 00:00:00+00:00
# 2021-09-09 10:54:04.789361477  _result  2245 1970-01-01 00:00:00+00:00
# 2021-09-09 10:54:04.796321630  _result  2246 1970-01-01 00:00:00+00:00
#
#                                                          _stop  \
# ts
# ...

# %%
fgw.traces(exp_id)
# Out:
#                                 result table                    _start  \
# sent
# 2021-09-09 15:35:01.651223898  _result     0 1970-01-01 00:00:00+00:00
# 2021-09-09 15:35:02.183430672  _result     1 1970-01-01 00:00:00+00:00
# 2021-09-09 15:35:02.699798107  _result     2 1970-01-01 00:00:00+00:00
# 2021-09-09 15:35:03.216401577  _result     3 1970-01-01 00:00:00+00:00
# 2021-09-09 15:35:03.736010790  _result     4 1970-01-01 00:00:00+00:00
#
#                                                          _stop  \
# sent
# 2021-09-09 15:35:01.651223898 2021-09-10 15:36:49.576624+00:00
# 2021-09-09 15:35:02.183430672 2021-09-10 15:36:49.576624+00:00
# 2021-09-09 15:35:02.699798107 2021-09-10 15:36:49.576624+00:00
# 2021-09-09 15:35:03.216401577 2021-09-10 15:36:49.576624+00:00
# 2021-09-09 15:35:03.736010790 2021-09-10 15:36:49.576624+00:00
#
#                                                          _time         value  \
# sent
# ...
